# %%
# full screen width of Jupyter notebook
from IPython.display import display, HTML
display(HTML("<style>.container {width:90%;} </style>")) 
display(HTML("<style>.toc{ margin-top: 100px;} </style>"))
# Out:
# <style>.container {width:90%;} </style>
# <style>.toc{ margin-top: 100px;} </style>

# %%
import os
os.environ['rz_token'] = '5bc2502a20241231'

# %%
import os
os.chdir('../../')

# %%
import runningz as rz
rz.TIMER()
# Out:
# [*] 2024/04/04 00:51:06 ------------------------------------------------------------ Timer = 4.51 seconds

# %% [markdown]
# # mlp_h

# %%
# H, MLP
# --------------------------------------------------> 289
params = { # 72
'random_state': 777,
'device': 'cpu',
'verbose': 1,
'num_workers': 4,
'n_jobs': 28,
'epochs': 11,
'batch_size': 8192,
'opt': 'Adam',
'lr': 0.0001,
'weight_decay': 1e-05,
'loss': 'mse',
'lr_decay': None,
'clip_grad': 0.95,
'ema_alpha': 0.999,
'layers': [
['FC:512', 'ReLU:', 'BatchNorm1d:momentum=0.01', 'Dropout:p=0.5'],
['FC:512', 'ReLU:', 'BatchNorm1d:momentum=0.01', 'Dropout:p=0.5'],
['FC:512', 'ReLU:', 'BatchNorm1d:momentum=0.01', 'Dropout:p=0.5'],
['FC:512', 'ReLU:', 'BatchNorm1d:momentum=0.01', 'Dropout:p=0.5'],
],
'dims': [512, 512, 512, 512],
'n_estimators': 9,
'ema_epochs': 3,
}
rz.dump_json(params, f'/Users/runningz/project/runningz/pipeline/cache/params/v3/mlp_h_289_1.json')

params = { # 07
'random_state': 777,
'device': 'cpu',
'verbose': 1,
'num_workers': 4,
'n_jobs': 28,
'epochs': 13,
'batch_size': 4096,
'opt': 'Adam',
'lr': 0.001,
'weight_decay': 1e-07,
'loss': 'mse',
'lr_decay': None,
'clip_grad': 0.9,
'ema_alpha': None,
'layers': [
['FC:512', 'BatchNorm1d:momentum=0.03', 'ReLU:', 'Dropout:p=0.4'],
['FC:512', 'BatchNorm1d:momentum=0.03', 'ReLU:', 'Dropout:p=0.4'],
['FC:512', 'BatchNorm1d:momentum=0.03', 'ReLU:', 'Dropout:p=0.4'],
['FC:512', 'BatchNorm1d:momentum=0.03', 'ReLU:', 'Dropout:p=0.4'],
],
'dims': [512, 512, 512, 512],
'n_estimators': 10,
'ema_epochs': 2,
}
rz.dump_json(params, f'/Users/runningz/project/runningz/pipeline/cache/params/v3/mlp_h_289_2.json')

params = { # 87
'random_state': 777,
'device': 'cpu',
'verbose': 1,
'num_workers': 4,
'n_jobs': 28,
'epochs': 15,
'batch_size': 4096,
'opt': 'Adam',
'lr': 0.0001,
'weight_decay': 1e-05,
'loss': 'mse',
'lr_decay': None,
'clip_grad': None,
'ema_alpha': 0.99,
'layers': [
['FC:512', 'ReLU:', 'BatchNorm1d:momentum=0.02', 'Dropout:p=0.2'],
['FC:512', 'ReLU:', 'BatchNorm1d:momentum=0.02', 'Dropout:p=0.2'],
['FC:512', 'ReLU:', 'BatchNorm1d:momentum=0.02', 'Dropout:p=0.2'],
],
'dims': [512, 512, 512],
'n_estimators': 10,
'ema_epochs': 2}
rz.dump_json(params, f'/Users/runningz/project/runningz/pipeline/cache/params/v3/mlp_h_289_3.json')

# --------------------------------------------------> 381
params = { # 52
'random_state': 777,
'device': 'cpu',
'verbose': 1,
'num_workers': 4,
'n_jobs': 28,
'epochs': 11,
'batch_size': 4096,
'opt': 'Adam',
'lr': 0.001,
'weight_decay': 1e-07,
'loss': 'mse',
'lr_decay': None,
'clip_grad': None,
'ema_alpha': None,
'layers': [
['FC:512', 'BatchNorm1d:momentum=0.02', 'ReLU:', 'Dropout:p=0.3'],
['FC:512', 'BatchNorm1d:momentum=0.02', 'ReLU:', 'Dropout:p=0.3'],
['FC:512', 'BatchNorm1d:momentum=0.02', 'ReLU:', 'Dropout:p=0.3'],
['FC:256', 'BatchNorm1d:momentum=0.02', 'ReLU:', 'Dropout:p=0.3'],
],
'dims': [512, 512, 512, 256],
'n_estimators': 12,
'ema_epochs': 2,
}
rz.dump_json(params, f'/Users/runningz/project/runningz/pipeline/cache/params/v3/mlp_h_381_1.json')

params = { # 13
'random_state': 777,
'device': 'cpu',
'verbose': 1,
'num_workers': 4,
'n_jobs': 28,
'epochs': 11,
'batch_size': 8192,
'opt': 'Adam',
'lr': 0.001,
'weight_decay': 1e-07,
'loss': 'mse',
'lr_decay': None,
'clip_grad': None,
'ema_alpha': None,
'layers': [
['FC:512', 'BatchNorm1d:momentum=0.05', 'ReLU:', 'Dropout:p=0.1'],
['FC:512', 'BatchNorm1d:momentum=0.05', 'ReLU:', 'Dropout:p=0.1'],
['FC:512', 'BatchNorm1d:momentum=0.05', 'ReLU:', 'Dropout:p=0.1'],
['FC:512', 'BatchNorm1d:momentum=0.05', 'ReLU:', 'Dropout:p=0.1'],
],
'dims': [512, 512, 512, 512],
'n_estimators': 9,
'ema_epochs': 3,
}
rz.dump_json(params, f'/Users/runningz/project/runningz/pipeline/cache/params/v3/mlp_h_381_2.json')

params = { # 17
'random_state': 777,
'device': 'cpu',
'verbose': 1,
'num_workers': 4,
'n_jobs': 28,
'epochs': 15,
'batch_size': 8192,
'opt': 'Adam',
'lr': 0.001,
'weight_decay': 1e-06,
'loss': 'mse',
'lr_decay': None,
'clip_grad': None,
'ema_alpha': 0.99,
'layers': [
['FC:512', 'ReLU:', 'BatchNorm1d:momentum=0.03', 'Dropout:p=0.2'],
['FC:512', 'ReLU:', 'BatchNorm1d:momentum=0.03', 'Dropout:p=0.2'],
['FC:512', 'ReLU:', 'BatchNorm1d:momentum=0.03', 'Dropout:p=0.2'],
['FC:512', 'ReLU:', 'BatchNorm1d:momentum=0.03', 'Dropout:p=0.2'],
],
'dims': [512, 512, 512, 512],
'n_estimators': 15,
'ema_epochs': 3,
}
rz.dump_json(params, f'/Users/runningz/project/runningz/pipeline/cache/params/v3/mlp_h_381_3.json')

# --------------------------------------------------> 656
params = {
'random_state': 777,
'device': 'cpu',
'verbose': 1,
'num_workers': 4,
'n_jobs': 28,
'epochs': 15,
'batch_size': 8192,
'opt': 'Adam',
'lr': 0.01,
'weight_decay': 1e-07,
'loss': 'mse',
'lr_decay': None,
'clip_grad': None,
'ema_alpha': None,
'layers': [
['FC:512', 'BatchNorm1d:momentum=0.02', 'ReLU:', 'Dropout:p=0.1'],
['FC:512', 'BatchNorm1d:momentum=0.02', 'ReLU:', 'Dropout:p=0.1'],
['FC:256', 'BatchNorm1d:momentum=0.02', 'ReLU:', 'Dropout:p=0.1'],
['FC:256', 'BatchNorm1d:momentum=0.02', 'ReLU:', 'Dropout:p=0.1'],
],
'dims': [512, 512, 256, 256],
'n_estimators': 11,
'ema_epochs': 3,
}
rz.dump_json(params, f'/Users/runningz/project/runningz/pipeline/cache/params/v3/mlp_h_656_1.json')

params = {
'random_state': 777,
'device': 'cpu',
'verbose': 1,
'num_workers': 4,
'n_jobs': 28,
'epochs': 10,
'batch_size': 4096,
'opt': 'Adam',
'lr': 0.001,
'weight_decay': 1e-07,
'loss': 'mse',
'lr_decay': None,
'clip_grad': 0.9,
'ema_alpha': None,
'layers': [
['FC:512', 'BatchNorm1d:momentum=0.03', 'ReLU:', 'Dropout:p=0.3'],
['FC:512', 'BatchNorm1d:momentum=0.03', 'ReLU:', 'Dropout:p=0.3'],
['FC:256', 'BatchNorm1d:momentum=0.03', 'ReLU:', 'Dropout:p=0.3'],
['FC:256', 'BatchNorm1d:momentum=0.03', 'ReLU:', 'Dropout:p=0.3'],
],
'dims': [512, 512, 256, 256],
'n_estimators': 9,
'ema_epochs': 2,
}
rz.dump_json(params, f'/Users/runningz/project/runningz/pipeline/cache/params/v3/mlp_h_656_2.json')

params = {
'random_state': 777,
'device': 'cpu',
'verbose': 1,
'num_workers': 4,
'n_jobs': 28,
'epochs': 11,
'batch_size': 4096,
'opt': 'Adam',
'lr': 0.01,
'weight_decay': 1e-07,
'loss': 'mse',
'lr_decay': None,
'clip_grad': 0.9,
'ema_alpha': None,
'layers': [
['FC:512', 'BatchNorm1d:momentum=0.04', 'ReLU:', 'Dropout:p=0.4'],
['FC:512', 'BatchNorm1d:momentum=0.04', 'ReLU:', 'Dropout:p=0.4'],
['FC:512', 'BatchNorm1d:momentum=0.04', 'ReLU:', 'Dropout:p=0.4'],
['FC:512', 'BatchNorm1d:momentum=0.04', 'ReLU:', 'Dropout:p=0.4'],
],
'dims': [512, 512, 512, 512],
'n_estimators': 8,
'ema_epochs': 2,
}
rz.dump_json(params, f'/Users/runningz/project/runningz/pipeline/cache/params/v3/mlp_h_656_3.json')

# --------------------------------------------------> 678
params = {
'random_state': 777,
'device': 'cpu',
'verbose': 1,
'num_workers': 4,
'n_jobs': 28,
'epochs': 15,
'batch_size': 8192,
'opt': 'Adam',
'lr': 0.01,
'weight_decay': 1e-07,
'loss': 'mse',
'lr_decay': None,
'clip_grad': None,
'ema_alpha': None,
'layers': [
['FC:512', 'BatchNorm1d:momentum=0.02', 'ReLU:', 'Dropout:p=0.1'],
['FC:512', 'BatchNorm1d:momentum=0.02', 'ReLU:', 'Dropout:p=0.1'],
['FC:256', 'BatchNorm1d:momentum=0.02', 'ReLU:', 'Dropout:p=0.1'],
['FC:256', 'BatchNorm1d:momentum=0.02', 'ReLU:', 'Dropout:p=0.1'],
],
'dims': [512, 512, 256, 256],
'n_estimators': 12,
'ema_epochs': 2,
}
rz.dump_json(params, f'/Users/runningz/project/runningz/pipeline/cache/params/v3/mlp_h_678_1.json')

params = {
'random_state': 777,
'device': 'cpu',
'verbose': 1,
'num_workers': 4,
'n_jobs': 28,
'epochs': 10,
'batch_size': 4096,
'opt': 'Adam',
'lr': 0.0001,
'weight_decay': 1e-07,
'loss': 'mse',
'lr_decay': None,
'clip_grad': None,
'ema_alpha': None,
'layers': [
['FC:512', 'ReLU:', 'BatchNorm1d:momentum=0.05', 'Dropout:p=0.1'],
['FC:512', 'ReLU:', 'BatchNorm1d:momentum=0.05', 'Dropout:p=0.1'],
['FC:512', 'ReLU:', 'BatchNorm1d:momentum=0.05', 'Dropout:p=0.1'],    
],
'dims': [512, 512,  512],
'n_estimators': 13,
'ema_epochs': 2,
}
rz.dump_json(params, f'/Users/runningz/project/runningz/pipeline/cache/params/v3/mlp_h_678_2.json')

params = {
'random_state': 777,
'device': 'cpu',
'verbose': 1,
'num_workers': 4,
'n_jobs': 28,
'epochs': 11,
'batch_size': 4096,
'opt': 'Adam',
'lr': 0.01,
'weight_decay': 1e-07,
'loss': 'mse',
'lr_decay': None,
'clip_grad': None,
'ema_alpha': 0.99,
'layers': [
['FC:512', 'BatchNorm1d:momentum=0.01', 'ReLU:', 'Dropout:p=0.3'],
['FC:512', 'BatchNorm1d:momentum=0.01', 'ReLU:', 'Dropout:p=0.3'],
['FC:512', 'BatchNorm1d:momentum=0.01', 'ReLU:', 'Dropout:p=0.3'],    
],
'dims': [512, 512, 512],
'n_estimators': 7,
'ema_epochs': 3,
}
rz.dump_json(params, f'/Users/runningz/project/runningz/pipeline/cache/params/v3/mlp_h_678_3.json')

# %% [markdown]
# # mlp_m

# %%
# --------------------------------------------------> 289
params = { # 1
'random_state': 777,
'device': 'cpu',
'verbose': 1,
'num_workers': 4,
'n_jobs': 28,
'epochs': 13,
'batch_size': 8192,
'opt': 'Adam',
'lr': 0.01,
'weight_decay': 1e-06,
'loss': 'mse',
'lr_decay': None,
'clip_grad': None,
'ema_alpha': None,
'layers': [
['FC:512', 'BatchNorm1d:momentum=0.04', 'ReLU:', 'Dropout:p=0.5'],
['FC:512', 'BatchNorm1d:momentum=0.04', 'ReLU:', 'Dropout:p=0.5'],
['FC:256', 'BatchNorm1d:momentum=0.04', 'ReLU:', 'Dropout:p=0.5'],    
],
'dims': [512, 512, 256],
'n_estimators': 9,
'ema_epochs': 1,
}
rz.dump_json(params, f'/Users/runningz/project/runningz/pipeline/cache/params/v3/mlp_m_289_1.json')

params = { # 2
'random_state': 777,
'device': 'cpu',
'verbose': 1,
'num_workers': 4,
'n_jobs': 28,
'epochs': 12,
'batch_size': 4096,
'opt': 'Adam',
'lr': 0.0001,
'weight_decay': 1e-06,
'loss': 'mse',
'lr_decay': None,
'clip_grad': None,
'ema_alpha': 0.999,
'layers': [
['FC:512', 'ReLU:', 'BatchNorm1d:momentum=0.02', 'Dropout:p=0.1'],
['FC:512', 'ReLU:', 'BatchNorm1d:momentum=0.02', 'Dropout:p=0.1'],
['FC:512', 'ReLU:', 'BatchNorm1d:momentum=0.02', 'Dropout:p=0.1'],
['FC:512', 'ReLU:', 'BatchNorm1d:momentum=0.02', 'Dropout:p=0.1'],    
],
'dims': [512, 512, 512, 512],
'n_estimators': 11,
'ema_epochs': 3,
}
rz.dump_json(params, f'/Users/runningz/project/runningz/pipeline/cache/params/v3/mlp_m_289_2.json')

params = { # 3
'random_state': 777,
'device': 'cpu',
'verbose': 1,
'num_workers': 4,
'n_jobs': 28,
'epochs': 14,
'batch_size': 4096,
'opt': 'Adam',
'lr': 0.0001,
'weight_decay': 1e-07,
'loss': 'mse',
'lr_decay': None,
'clip_grad': None,
'ema_alpha': None,
'layers': [
['FC:512', 'ReLU:', 'BatchNorm1d:momentum=0.01', 'Dropout:p=0.4'],
['FC:512', 'ReLU:', 'BatchNorm1d:momentum=0.01', 'Dropout:p=0.4'],
['FC:512', 'ReLU:', 'BatchNorm1d:momentum=0.01', 'Dropout:p=0.4'],
['FC:512', 'ReLU:', 'BatchNorm1d:momentum=0.01', 'Dropout:p=0.4'],    
],
'dims': [512, 512, 512, 512],
'n_estimators': 14,
'ema_epochs': 3,
}
rz.dump_json(params, f'/Users/runningz/project/runningz/pipeline/cache/params/v3/mlp_m_289_3.json')

# --------------------------------------------------> 381
params = { # 1
'random_state': 777,
'device': 'cpu',
'verbose': 1,
'num_workers': 4,
'n_jobs': 28,
'epochs': 10,
'batch_size': 8192,
'opt': 'Adam',
'lr': 0.0001,
'weight_decay': 1e-06,
'loss': 'mse',
'lr_decay': None,
'clip_grad': 0.9,
'ema_alpha': 0.999,
'layers': [
['FC:512', 'ReLU:', 'BatchNorm1d:momentum=0.03', 'Dropout:p=0.4'],
['FC:512', 'ReLU:', 'BatchNorm1d:momentum=0.03', 'Dropout:p=0.4'],
['FC:512', 'ReLU:', 'BatchNorm1d:momentum=0.03', 'Dropout:p=0.4'],
['FC:512', 'ReLU:', 'BatchNorm1d:momentum=0.03', 'Dropout:p=0.4'],    
],
'dims': [512, 512, 512, 512],
'n_estimators': 9,
'ema_epochs': 1,
}
rz.dump_json(params, f'/Users/runningz/project/runningz/pipeline/cache/params/v3/mlp_m_381_1.json')

params = { # 2
'random_state': 777,
'device': 'cpu',
'verbose': 1,
'num_workers': 4,
'n_jobs': 28,
'epochs': 14,
'batch_size': 4096,
'opt': 'Adam',
'lr': 0.001,
'weight_decay': 1e-07,
'loss': 'mse',
'lr_decay': None,
'clip_grad': None,
'ema_alpha': 0.99,
'layers': [
['FC:512', 'BatchNorm1d:momentum=0.01', 'ReLU:', 'Dropout:p=0.3'],
['FC:512', 'BatchNorm1d:momentum=0.01', 'ReLU:', 'Dropout:p=0.3'],
['FC:512', 'BatchNorm1d:momentum=0.01', 'ReLU:', 'Dropout:p=0.3'],    
],
'dims': [512, 512, 512],
'n_estimators': 8,
'ema_epochs': 2,
}
rz.dump_json(params, f'/Users/runningz/project/runningz/pipeline/cache/params/v3/mlp_m_381_2.json')

params = { # 3
'random_state': 777,
'device': 'cpu',
'verbose': 1,
'num_workers': 4,
'n_jobs': 28,
'epochs': 14,
'batch_size': 4096,
'opt': 'Adam',
'lr': 0.0001,
'weight_decay': 1e-07,
'loss': 'mse',
'lr_decay': None,
'clip_grad': None,
'ema_alpha': None,
'layers': [
['FC:512', 'BatchNorm1d:momentum=0.01', 'ReLU:', 'Dropout:p=0.3'],
['FC:512', 'BatchNorm1d:momentum=0.01', 'ReLU:', 'Dropout:p=0.3'],
['FC:512', 'BatchNorm1d:momentum=0.01', 'ReLU:', 'Dropout:p=0.3'],
['FC:256', 'BatchNorm1d:momentum=0.01', 'ReLU:', 'Dropout:p=0.3'],    
],
'dims': [512, 512, 512, 256],
'n_estimators': 14,
'ema_epochs': 3,
}
rz.dump_json(params, f'/Users/runningz/project/runningz/pipeline/cache/params/v3/mlp_m_381_3.json')

# --------------------------------------------------> 656
params = { # 1
'random_state': 777,
'device': 'cpu',
'verbose': 1,
'num_workers': 4,
'n_jobs': 28,
'epochs': 11,
'batch_size': 8192,
'opt': 'Adam',
'lr': 0.01,
'weight_decay': 1e-07,
'loss': 'mse',
'lr_decay': None,
'clip_grad': None,
'ema_alpha': None,
'layers': [
['FC:512', 'BatchNorm1d:momentum=0.02', 'ReLU:', 'Dropout:p=0.1'],
['FC:512', 'BatchNorm1d:momentum=0.02', 'ReLU:', 'Dropout:p=0.1'],
['FC:256', 'BatchNorm1d:momentum=0.02', 'ReLU:', 'Dropout:p=0.1'],
['FC:256', 'BatchNorm1d:momentum=0.02', 'ReLU:', 'Dropout:p=0.1'],
],
'dims': [512, 512, 256, 256],
'n_estimators': 11,
'ema_epochs': 3,
}
rz.dump_json(params, f'/Users/runningz/project/runningz/pipeline/cache/params/v3/mlp_m_656_1.json')

params = { # 2
'random_state': 777,
'device': 'cpu',
'verbose': 1,
'num_workers': 4,
'n_jobs': 28,
'epochs': 12,
'batch_size': 4096,
'opt': 'Adam',
'lr': 0.0001,
'weight_decay': 1e-06,
'loss': 'mse',
'lr_decay': None,
'clip_grad': None,
'ema_alpha': None,
'layers': [
['FC:512', 'ReLU:', 'BatchNorm1d:momentum=0.03', 'Dropout:p=0.3'],
['FC:512', 'ReLU:', 'BatchNorm1d:momentum=0.03', 'Dropout:p=0.3'],
['FC:512', 'ReLU:', 'BatchNorm1d:momentum=0.03', 'Dropout:p=0.3'],   
['FC:512', 'ReLU:', 'BatchNorm1d:momentum=0.03', 'Dropout:p=0.3'],    
],
'dims': [512, 512, 512, 512],
'n_estimators': 12,
'ema_epochs': 1,
}
rz.dump_json(params, f'/Users/runningz/project/runningz/pipeline/cache/params/v3/mlp_m_656_2.json')

params = { # 3
'random_state': 777,
'device': 'cpu',
'verbose': 1,
'num_workers': 4,
'n_jobs': 28,
'epochs': 12,
'batch_size': 4096,
'opt': 'Adam',
'lr': 0.001,
'weight_decay': 1e-07,
'loss': 'mse',
'lr_decay': None,
'clip_grad': None,
'ema_alpha': None,
'layers': [
['FC:512', 'ReLU:', 'BatchNorm1d:momentum=0.03', 'Dropout:p=0.5'],
['FC:512', 'ReLU:', 'BatchNorm1d:momentum=0.03', 'Dropout:p=0.5'],
['FC:512', 'ReLU:', 'BatchNorm1d:momentum=0.03', 'Dropout:p=0.5'],   
['FC:512', 'ReLU:', 'BatchNorm1d:momentum=0.03', 'Dropout:p=0.5'],       
],
'dims': [512, 512, 512, 512],
'n_estimators': 12,
'ema_epochs': 1,
}
rz.dump_json(params, f'/Users/runningz/project/runningz/pipeline/cache/params/v3/mlp_m_656_3.json')

# --------------------------------------------------> 678
params = { # 1
'random_state': 777,
'device': 'cpu',
'verbose': 1,
'num_workers': 4,
'n_jobs': 28,
'epochs': 15,
'batch_size': 8192,
'opt': 'Adam',
'lr': 0.01,
'weight_decay': 1e-05,
'loss': 'mse',
'lr_decay': None,
'clip_grad': None,
'ema_alpha': None,
'layers': [
['FC:512', 'ReLU:', 'BatchNorm1d:momentum=0.02', 'Dropout:p=0.1'],
['FC:512', 'ReLU:', 'BatchNorm1d:momentum=0.02', 'Dropout:p=0.1'],
['FC:256', 'ReLU:', 'BatchNorm1d:momentum=0.02', 'Dropout:p=0.1'],    
],
'dims': [512, 512, 256],
'n_estimators': 9,
'ema_epochs': 3,
}
rz.dump_json(params, f'/Users/runningz/project/runningz/pipeline/cache/params/v3/mlp_m_678_1.json')

params = { # 2
'random_state': 777,
'device': 'cpu',
'verbose': 1,
'num_workers': 4,
'n_jobs': 28,
'epochs': 14,
'batch_size': 8192,
'opt': 'Adam',
'lr': 0.01,
'weight_decay': 1e-06,
'loss': 'mse',
'lr_decay': None,
'clip_grad': None,
'ema_alpha': None,
'layers': [
['FC:512', 'BatchNorm1d:momentum=0.02', 'ReLU:', 'Dropout:p=0.2'],    
['FC:256', 'BatchNorm1d:momentum=0.02', 'ReLU:', 'Dropout:p=0.2'],    
['FC:256', 'BatchNorm1d:momentum=0.02', 'ReLU:', 'Dropout:p=0.2'],        
],
'dims': [512, 256, 256],
'n_estimators': 11,
'ema_epochs': 2,
}
rz.dump_json(params, f'/Users/runningz/project/runningz/pipeline/cache/params/v3/mlp_m_678_2.json')

params = { # 3
'random_state': 777,
'device': 'cpu',
'verbose': 1,
'num_workers': 4,
'n_jobs': 28,
'epochs': 13,
'batch_size': 4096,
'opt': 'Adam',
'lr': 0.0001,
'weight_decay': 1e-05,
'loss': 'mse',
'lr_decay': None,
'clip_grad': None,
'ema_alpha': 0.99,
'layers': [
['FC:512', 'ReLU:', 'BatchNorm1d:momentum=0.02', 'Dropout:p=0.2'],
['FC:512', 'ReLU:', 'BatchNorm1d:momentum=0.02', 'Dropout:p=0.2'],
['FC:512', 'ReLU:', 'BatchNorm1d:momentum=0.02', 'Dropout:p=0.2'],   
],
'dims': [512, 512, 512],
'n_estimators': 11,
'ema_epochs': 3,
}
rz.dump_json(params, f'/Users/runningz/project/runningz/pipeline/cache/params/v3/mlp_m_678_3.json')

# %% [markdown]
# # lgb_h

# %%
params_base = {'seed': 777,
'objective': 'regression',
'metric': 'rmse',
'n_jobs': 63,
'verbosity': -1,
'device_type': 'cpu',
}

# %%
# ------------------------------> 289
params = {
 'n_estimators': 1900,
 'learning_rate': 0.004,
 'num_leaves': 412,
 'bagging_fraction': 0.9,
 'feature_fraction': 0.25,
 'max_depth': 8,
 'min_data_in_leaf': 310,
 'max_bin': 127,
 'extra_tree': True,
 'n_boost': 1400,
}
params = {**params_base, **params}
rz.dump_json(params, f'/Users/runningz/project/runningz/pipeline/cache/params/v3/lgb_h_289_1.json')

params = {
 'n_estimators': 2300,
 'learning_rate': 0.008,
 'num_leaves': 474,
 'bagging_fraction': 0.775,
 'feature_fraction': 0.625,
 'max_depth': 8,
 'min_data_in_leaf': 90,
 'max_bin': 255,
 'extra_tree': True,
 'n_boost': 600,
}
params = {**params_base, **params}
rz.dump_json(params, f'/Users/runningz/project/runningz/pipeline/cache/params/v3/lgb_h_289_2.json')
params = {
 'n_estimators': 1900,
 'learning_rate': 0.003,
 'num_leaves': 320,
 'bagging_fraction': 0.225,
 'feature_fraction': 0.5,
 'max_depth': 12,
 'min_data_in_leaf': 160,
 'max_bin': 255,
 'extra_tree': True,
 'n_boost': 1000,
}
params = {**params_base, **params}
rz.dump_json(params, f'/Users/runningz/project/runningz/pipeline/cache/params/v3/lgb_h_289_3.json')

# ------------------------------> 381
params = {
 'n_estimators': 2200,
 'learning_rate': 0.009,
 'num_leaves': 1064,
 'bagging_fraction': 0.4,
 'feature_fraction': 0.15,
 'max_depth': 12,
 'min_data_in_leaf': 80,
 'max_bin': 15,
 'extra_tree': False,
 'n_boost': 1000,
}
params = {**params_base, **params}
rz.dump_json(params, f'/Users/runningz/project/runningz/pipeline/cache/params/v3/lgb_h_381_1.json')
params = {
 'n_estimators': 2400,
 'learning_rate': 0.01,
 'num_leaves': 1927,
 'bagging_fraction': 0.175,
 'feature_fraction': 0.3,
 'max_depth': -1,
 'min_data_in_leaf': 480,
 'max_bin': 63,
 'extra_tree': True,
 'n_boost': 600,
}
params = {**params_base, **params}
rz.dump_json(params, f'/Users/runningz/project/runningz/pipeline/cache/params/v3/lgb_h_381_2.json')
params = {
 'n_estimators': 2700,
 'learning_rate': 0.007,
 'num_leaves': 428,
 'bagging_fraction': 0.8,
 'feature_fraction': 0.375,
 'max_depth': -1,
 'min_data_in_leaf': 370,
 'max_bin': 63,
 'extra_tree': True,
 'n_boost': 1000,
}
params = {**params_base, **params}
rz.dump_json(params, f'/Users/runningz/project/runningz/pipeline/cache/params/v3/lgb_h_381_3.json')

# ------------------------------> 656
params = {
 'n_estimators': 1300,
 'learning_rate': 0.008,
 'num_leaves': 439,
 'bagging_fraction': 0.5,
 'feature_fraction': 0.475,
 'max_depth': -1,
 'min_data_in_leaf': 480,
 'max_bin': 53,
 'extra_tree': False,
 'n_boost': 1000,
}
params = {**params_base, **params}
rz.dump_json(params, f'/Users/runningz/project/runningz/pipeline/cache/params/v3/lgb_h_656_1.json')
params = {
 'n_estimators': 2700,
 'learning_rate': 0.007,
 'num_leaves': 428,
 'bagging_fraction': 0.8,
 'feature_fraction': 0.375,
 'max_depth': -1,
 'min_data_in_leaf': 370,
 'max_bin': 63,
 'extra_tree': True,
 'n_boost': 1700,
}
params = {**params_base, **params}
rz.dump_json(params, f'/Users/runningz/project/runningz/pipeline/cache/params/v3/lgb_h_656_2.json')
params = {
 'n_estimators': 2800,
 'learning_rate': 0.002,
 'num_leaves': 395,
 'bagging_fraction': 0.65,
 'feature_fraction': 0.175,
 'max_depth': -1,
 'min_data_in_leaf': 250,
 'max_bin': 63,
 'extra_tree': False,
 'n_boost': 2800,
}
params = {**params_base, **params}
rz.dump_json(params, f'/Users/runningz/project/runningz/pipeline/cache/params/v3/lgb_h_656_3.json')

# ------------------------------> 678
params = {
 'n_estimators': 2400,
 'learning_rate': 0.006,
 'num_leaves': 740,
 'bagging_fraction': 0.65,
 'feature_fraction': 0.55,
 'max_depth': 12,
 'min_data_in_leaf': 130,
 'max_bin': 255,
 'extra_tree': False,
 'n_boost': 1300,
}
params = {**params_base, **params}
rz.dump_json(params, f'/Users/runningz/project/runningz/pipeline/cache/params/v3/lgb_h_678_1.json')

params = {
 'n_estimators': 3000,
 'learning_rate': 0.002,
 'num_leaves': 1085,
 'bagging_fraction': 0.725,
 'feature_fraction': 0.55,
 'max_depth': 12,
 'min_data_in_leaf': 110,
 'max_bin': 127,
 'extra_tree': False,
 'n_boost': 3000,
}
params = {**params_base, **params}
rz.dump_json(params, f'/Users/runningz/project/runningz/pipeline/cache/params/v3/lgb_h_678_2.json')

params = {
 'n_estimators': 1400,
 'learning_rate': 0.008,
 'num_leaves': 603,
 'bagging_fraction': 0.625,
 'feature_fraction': 0.75,
 'max_depth': 12,
 'min_data_in_leaf': 300,
 'max_bin': 255,
 'extra_tree': False,
 'n_boost': 1200,
}
params = {**params_base, **params}
rz.dump_json(params, f'/Users/runningz/project/runningz/pipeline/cache/params/v3/lgb_h_678_3.json')

# %% [markdown]
# # lgb_m

# %%
# ------------------------------> 289
params = {
 'n_estimators': 1600,
 'learning_rate': 0.009,
 'num_leaves': 528,
 'bagging_fraction': 0.825,
 'feature_fraction': 0.6,
 'max_depth': 8,
 'min_data_in_leaf': 150,
 'max_bin': 15,
 'extra_tree': True,
 'n_boost': 900,
}
params = {**params_base, **params}
rz.dump_json(params, f'/Users/runningz/project/runningz/pipeline/cache/params/v3/lgb_m_289_1.json')
params = {
 'n_estimators': 1800,
 'learning_rate': 0.007,
 'num_leaves': 881,
 'bagging_fraction': 0.5,
 'feature_fraction': 0.5,
 'max_depth': 8,
 'min_data_in_leaf': 160,
 'max_bin': 15,
 'extra_tree': True,
 'n_boost': 900,
}
params = {**params_base, **params}
rz.dump_json(params, f'/Users/runningz/project/runningz/pipeline/cache/params/v3/lgb_m_289_2.json')
params = {
 'n_estimators': 2100,
 'learning_rate': 0.002,
 'num_leaves': 375,
 'bagging_fraction': 0.8,
 'feature_fraction': 0.6,
 'max_depth': 12,
 'min_data_in_leaf': 370,
 'max_bin': 63,
 'extra_tree': True,
 'n_boost': 2100,
}
params = {**params_base, **params}
rz.dump_json(params, f'/Users/runningz/project/runningz/pipeline/cache/params/v3/lgb_m_289_3.json')

# ------------------------------> 381
params = {
 'n_estimators': 2800,
 'learning_rate': 0.002,
 'num_leaves': 395,
 'bagging_fraction': 0.65,
 'feature_fraction': 0.175,
 'max_depth': -1,
 'min_data_in_leaf': 250,
 'max_bin': 63,
 'extra_tree': False,
 'n_boost': 1600,
}
params = {**params_base, **params}
rz.dump_json(params, f'/Users/runningz/project/runningz/pipeline/cache/params/v3/lgb_m_381_1.json')
params = {
 'n_estimators': 2800,
 'learning_rate': 0.007,
 'num_leaves': 657,
 'bagging_fraction': 0.425,
 'feature_fraction': 0.625,
 'max_depth': 8,
 'min_data_in_leaf': 240,
 'max_bin': 255,
 'extra_tree': False,
 'n_boost': 500,
}
params = {**params_base, **params}
rz.dump_json(params, f'/Users/runningz/project/runningz/pipeline/cache/params/v3/lgb_m_381_2.json')
params = {
 'n_estimators': 2200,
 'learning_rate': 0.002,
 'num_leaves': 1622,
 'bagging_fraction': 0.95,
 'feature_fraction': 0.725,
 'max_depth': 8,
 'min_data_in_leaf': 250,
 'max_bin': 127,
 'extra_tree': False,
 'n_boost': 1600,
}
params = {**params_base, **params}
rz.dump_json(params, f'/Users/runningz/project/runningz/pipeline/cache/params/v3/lgb_m_381_3.json')



# ------------------------------> 656
params = {
 'n_estimators': 2800,
 'learning_rate': 0.002,
 'num_leaves': 395,
 'bagging_fraction': 0.65,
 'feature_fraction': 0.175,
 'max_depth': -1,
 'min_data_in_leaf': 250,
 'max_bin': 63,
 'extra_tree': False,
 'n_boost': 2800,
}
params = {**params_base, **params}
rz.dump_json(params, f'/Users/runningz/project/runningz/pipeline/cache/params/v3/lgb_m_656_1.json')
params = {
 'n_estimators': 1300,
 'learning_rate': 0.004,
 'num_leaves': 810,
 'bagging_fraction': 0.2,
 'feature_fraction': 0.55,
 'max_depth': -1,
 'min_data_in_leaf': 450,
 'max_bin': 127,
 'extra_tree': True,
 'n_boost': 1300,
}
params = {**params_base, **params}
rz.dump_json(params, f'/Users/runningz/project/runningz/pipeline/cache/params/v3/lgb_m_656_2.json')
params = {
 'n_estimators': 2300,
 'learning_rate': 0.007,
 'num_leaves': 483,
 'bagging_fraction': 0.975,
 'feature_fraction': 0.575,
 'max_depth': -1,
 'min_data_in_leaf': 270,
 'max_bin': 127,
 'extra_tree': False,
 'n_boost': 700,
}
params = {**params_base, **params}
rz.dump_json(params, f'/Users/runningz/project/runningz/pipeline/cache/params/v3/lgb_m_656_3.json')

# ------------------------------> 678
params = {
 'n_estimators': 1900,
 'learning_rate': 0.004,
 'num_leaves': 412,
 'bagging_fraction': 0.9,
 'feature_fraction': 0.25,
 'max_depth': 8,
 'min_data_in_leaf': 310,
 'max_bin': 127,
 'extra_tree': True,
 'n_boost': 1900,
}
params = {**params_base, **params}
rz.dump_json(params, f'/Users/runningz/project/runningz/pipeline/cache/params/v3/lgb_m_678_1.json')
params = {
 'n_estimators': 2200,
 'learning_rate': 0.005,
 'num_leaves': 281,
 'bagging_fraction': 0.575,
 'feature_fraction': 0.225,
 'max_depth': -1,
 'min_data_in_leaf': 410,
 'max_bin': 255,
 'extra_tree': True,
 'n_boost': 1300,
}
params = {**params_base, **params}
rz.dump_json(params, f'/Users/runningz/project/runningz/pipeline/cache/params/v3/lgb_m_678_2.json')
params = {
 'n_estimators': 2300,
 'learning_rate': 0.008,
 'num_leaves': 475,
 'bagging_fraction': 0.775,
 'feature_fraction': 0.625,
 'max_depth': 8,
 'min_data_in_leaf': 90,
 'max_bin': 255,
 'extra_tree': True,
 'n_boost': 800,
}
params = {**params_base, **params}
rz.dump_json(params, f'/Users/runningz/project/runningz/pipeline/cache/params/v3/lgb_m_678_3.json')

# %%
path = '/Users/runningz/project/runningz/pipeline/cache/params/v3/'
fnames = [x for x in os.listdir(path) if 'lgb' in x]

# %%
for fname in fnames:
    p = rz.load_json(f'{path}/{fname}')
    p['n_estimators'] = p['n_boost']
    del p['n_boost']
    rz.dump_json(p, f'{path}/{fname}')
